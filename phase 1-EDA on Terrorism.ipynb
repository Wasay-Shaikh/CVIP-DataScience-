# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Load .CSV file

# %%
df=pd.read_csv('globalterrorism.csv', encoding='latin-1')
df.head()
# Out:
# C:\Users\shaik\AppData\Local\Temp\ipykernel_4672\776114391.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('globalterrorism.csv', encoding='latin-1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Counting Columns with Missing Values in DataFrame 'df'

# %%
nul = [i for i in df.columns if df[i].isna().sum() > 0]
len(nul)
# Out:
# 106

# %% [markdown]
# ### Remove Columns with Missing Values in DataFrame 'df'

# %%
df.dropna(axis=1, inplace=True)
print(df.shape)
# Out:
# (181691, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 29 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   eventid          181691 non-null  int64
#  1   iyear            181691 non-null  int64
#  2   imonth           181691 non-null  int64
#  3   iday             181691 non-null  int64
#  4   extended         181691 non-null  int64
#  5   country          181691 non-null  int64
#  6   country_txt      181691 non-null  object
#  7   region           181691 non-null  int64
#  8   region_txt       181691 non-null  object
#  9   vicinity         181691 non-null  int64
#  10  crit1            181691 non-null  int64
#  11  crit2            181691 non-null  int64
#  12  crit3            181691 non-null  int64
#  13  success          181691 non-null  int64
#  14  suicide          181691 non-null  int64
#  15  attacktype1      181691 non-null  int64
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       vicinity  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean        0.045346     131.968501       7.160938       0.068297
# std         0.208063     112.414535       2.933408       0.284553
# min         0.000000       4.000000       1.000000      -9.000000
# ...

# %% [markdown]
# ## Number of Incidents each month

# %%
sns.set_theme(style='darkgrid', font_scale=1.2)  # Increase the font size and set the style

plt.figure(figsize=(15, 7))
ax = sns.countplot(data=df, x='imonth')
plt.xticks(ha='right')  # Rotate x-axis labels and align them to the right
plt.xlabel('Month', labelpad=18)  # Add some padding to the x-axis label
plt.ylabel('Incident Count', labelpad=15)  # Add some padding to the y-axis label
plt.title('Incident Count Per Month (Overall)', pad=25)  # Add some padding to the title

# Annotate bars with counts
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=12, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Number of Terror Activities Each Year

# %%
plt.figure(figsize=(15, 8))
sns.set_theme(style='darkgrid', font_scale=1.2)  # Increase the font size

sns.countplot(x='iyear', data=df, edgecolor='black', palette='viridis')  # Use a different color palette
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels and align them to the right
plt.xlabel('Year of Attack', labelpad=15)  # Add some padding to the x-axis label
plt.ylabel('Number of Terrorist Activities', labelpad=15)  # Add some padding to the y-axis label
plt.title('Number of Terrorist Activities Each Year', pad=20)  # Add some padding to the title

plt.tight_layout()
plt.show()

# %%
df['attacktype1_txt'].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
sns.set_theme(style='darkgrid', font_scale=1.2, palette='Set1')  # Increase the font size and set the style

plt.figure(figsize=(12, 7))
ax = sns.countplot(x='attacktype1_txt', data=df, order=df['attacktype1_txt'].value_counts().index)
plt.xticks(rotation=45, ha='right', fontsize=8)  # Rotate x-axis labels and align them to the right
plt.xlabel('Attack Type', labelpad=15)  # Add some padding to the x-axis label
plt.ylabel('Number of Attacks', labelpad=15)  # Add some padding to the y-axis label
plt.title('Attacking Methods by Terrorists', pad=20)  # Add some padding to the title

# Annotate bars with counts
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=10, color='black', xytext=(0, 2),
                textcoords='offset points')

plt.tight_layout()
plt.show()

# %%
df['targtype1_txt'].value_counts()
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: targtype1_txt, dtype: int64

# %%
sns.set_theme(style='darkgrid', font_scale=1.2, palette='Set1')  # Increase the font size and set the style

plt.figure(figsize=(12, 7))
ax = sns.countplot(x='targtype1_txt', data=df, order=df['targtype1_txt'].value_counts().index)
plt.xticks(rotation=45, ha='right', fontsize=8)  # Rotate x-axis labels and align them to the right
plt.xlabel('Target Type', labelpad=15)  # Add some padding to the x-axis label
plt.ylabel('Number of Attacks', labelpad=15)  # Add some padding to the y-axis label
plt.title('Attacking Target by Terrorists', pad=20)  # Add some padding to the title

# Annotate bars with counts
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=8, color='black', xytext=(0, 2),
                textcoords='offset points')

plt.tight_layout()
plt.show()

# %%
df['weaptype1_txt'].value_counts()
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# ...

# %%
sns.set_theme(style='darkgrid', font_scale=1.2, palette='Set1')  # Increase the font size and set the style

plt.figure(figsize=(12, 10))
ax = sns.countplot(x='weaptype1_txt', data=df, order=df['weaptype1_txt'].value_counts().index)
plt.xticks(rotation=45, ha='right', fontsize=8)  # Rotate x-axis labels and align them to the right
plt.xlabel('Weapon Type', labelpad=15)  # Add some padding to the x-axis label
plt.ylabel('Number of Attacks', labelpad=15)  # Add some padding to the y-axis label
plt.title('Weapons Used while Attacking by Terrorists', pad=20)  # Add some padding to the title

# Annotate bars with counts
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=8, color='black', xytext=(0, 2),
                textcoords='offset points')

plt.tight_layout()
plt.show()

# %%
plt.subplots(figsize=(15,5))
sns.countplot(x='country_txt',data=df,palette='inferno',order=df['country_txt'].value_counts()[:15].index)
plt.xticks(rotation=90)
plt.xlabel('Countries')
plt.title('Number Of Terrorist Activities By Countries')
# Out:
# Text(0.5, 1.0, 'Number Of Terrorist Activities By Countries')

# %% [markdown]
# ## Terrorist Organisation with Highest Terror Attacks

# %%
sns.set_theme(style='darkgrid', font_scale=1.2, palette='inferno')  # Increase the font size and set the style

plt.figure(figsize=(10, 8))
sns.barplot(x=df['gname'].value_counts()[1:16].index, y=df['gname'].value_counts()[1:16].values)
plt.xticks(rotation=45, ha='right', fontsize=10)  # Rotate x-axis labels and align them to the right
plt.xlabel('Terrorist Organization', labelpad=15)  # Add some padding to the x-axis label
plt.ylabel('Number of Terror Attacks', labelpad=10)  # Add some padding to the y-axis label
plt.title('Terrorist Organizations with Highest Terror Attacks', pad=20)  # Add some padding to the title

# Annotate bars with counts
for index, value in enumerate(df['gname'].value_counts()[1:16].values):
    plt.text(index, value, str(value), ha='center', va='bottom', fontsize=8, color='black')

plt.tight_layout()
plt.show()

# %%
sns.set_theme(style='darkgrid', font_scale=1.2, palette='viridis')  # Increase the font size and set the style

plt.figure(figsize=(18, 12))
# Use the orient parameter to create a horizontal bar plot
ax = sns.barplot(x=df['region_txt'].value_counts().values, y=df['region_txt'].value_counts().index, orient='h')  
# Add some padding to the x-axis label
plt.xlabel('Number of Terror Attacks', labelpad=15)  
# Add some padding to the y-axis label
plt.ylabel('Region', labelpad=15)  
# Add some padding to the title
plt.title('Top Regions Affected by Terrorism', pad=20)

# Annotate bars with counts
for index, value in enumerate(df['region_txt'].value_counts().values):
    ax.text(value, index, str(value), ha='left', va='center', fontsize=13, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Wasay Ahmed Shaikh
